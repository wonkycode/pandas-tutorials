# %% [markdown]
# # The <code>rank()</code> Method
# By:<a href='https://www.youtube.com/wonkyCode'>WonkyCode</a>
#
# Pandas <code>Dataframe.rank()</code> method returns a rank of every respective index of a series passed. The rank is returned on the basis of position after sorting.
#
# By default, equal values are assigned a rank that is the average of the ranks of those values.

# %%
import pandas as pd

data = pd.read_csv("datasets/basketball.csv").dropna(how="all")

# %%
data.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989  06-May
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990  06-Mar
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996  06-Jun
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994  06-Nov
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998  06-Feb
#
# ...

# %%
data["PTS"] = data["PTS"].fillna(0).astype("int")

# %%
data.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989  06-May
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990  06-Mar
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996  06-Jun
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994  06-Nov
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998  06-Feb
#
# ...

# %%
data["PTS"].max()
# Out:
# 2832

# %%
data["PTS"].min()
# Out:
# 0

# %%
data["PTS"].rank()
# Out:
# 0        53781.0
# 1        53708.5
# 2        53662.0
# 3        53659.5
# 4        53607.0
#           ...
# 53793      585.0
# 53794      522.0
# 53795      464.5
# 53796      414.0
# 53797      333.5
# Name: PTS, Length: 53798, dtype: float64

# %%
data["PTS"].rank(ascending=False)
# Out:
# 0           18.0
# 1           90.5
# 2          137.0
# 3          139.5
# 4          192.0
#           ...
# 53793    53214.0
# 53794    53277.0
# 53795    53334.5
# 53796    53385.0
# 53797    53465.5
# Name: PTS, Length: 53798, dtype: float64

# %%
data["PTS"].rank(ascending=False).astype("int")
# Out:
# 0           18
# 1           90
# 2          137
# 3          139
# 4          192
#          ...
# 53793    53214
# 53794    53277
# 53795    53334
# 53796    53385
# 53797    53465
# Name: PTS, Length: 53798, dtype: int32

# %%
data["Rank by PTS"] = data["PTS"].rank(ascending=False).astype("int")

# %%
data.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...      1989.0          Aug  Aug 26, 1989  06-May
# 1  624  1349  270  ...      1990.0          Jul  Jul 15, 1990  06-Mar
# 2  627  1283  141  ...      1996.0          Oct  Oct 30, 1996  06-Jun
# 3  685  1238   89  ...      1994.0          Dec   Dec 6, 1994  06-Nov
# 4  546  1249  205  ...      1998.0          Sep  Sep 19, 1998  06-Feb
#
# ...
