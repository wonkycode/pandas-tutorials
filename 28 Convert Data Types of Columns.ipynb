# %% [markdown]
# # The <code>astype()</code> Method
# By:<a href='https://www.youtube.com/wonkyCode'>WonkyCode</a>

# %%
import pandas as pd

data = pd.read_csv("datasets/basketball.csv").dropna(how="all")

# %%
data.head()
# Out:
#   League       Season           Stage                 Player Team  GP     MIN  \
# 0    NBA  2019 - 2020  Regular_Season           James Harden  HOU  68  2482.6
# 1    NBA  2019 - 2020  Regular_Season         Damian Lillard  POR  66  2473.7
# 2    NBA  2019 - 2020  Regular_Season           Devin Booker  PHX  70  2511.8
# 3    NBA  2019 - 2020  Regular_Season  Giannis Antetokounmpo  MIL  63  1916.9
# 4    NBA  2019 - 2020  Regular_Season             Trae Young  ATL  60  2120.1
#
#    FGM   FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  672  1514  299  ...  2335      1989.0          Aug  Aug 26, 1989  06-May
# 1  624  1349  270  ...  1978      1990.0          Jul  Jul 15, 1990  06-Mar
# 2  627  1283  141  ...  1863      1996.0          Oct  Oct 30, 1996  06-Jun
# 3  685  1238   89  ...  1857      1994.0          Dec   Dec 6, 1994  06-Nov
# 4  546  1249  205  ...  1778      1998.0          Sep  Sep 19, 1998  06-Feb
#
# ...

# %%
data.dtypes
# Out:
# League          object
# Season          object
# Stage           object
# Player          object
# Team            object
# GP               int64
# MIN            float64
# FGM              int64
# FGA              int64
# 3PM              int64
# 3PA              int64
# FTM              int64
# FTA              int64
# TOV              int64
# PF               int64
# ORB              int64
# DRB              int64
# REB              int64
# AST              int64
# STL              int64
# BLK              int64
# PTS              int64
# birth_year     float64
# birth_month     object
# birth_date      object
# height          object
# height_cm      float64
# weight         float64
# weight_kg      float64
# nationality     object
# high_school     object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       53798 non-null  object
#  1   Season       53798 non-null  object
#  2   Stage        53798 non-null  object
#  3   Player       53798 non-null  object
#  4   Team         53787 non-null  object
#  5   GP           53798 non-null  int64
#  6   MIN          53798 non-null  float64
#  7   FGM          53798 non-null  int64
#  8   FGA          53798 non-null  int64
#  9   3PM          53798 non-null  int64
#  10  3PA          53798 non-null  int64
#  11  FTM          53798 non-null  int64
#  12  FTA          53798 non-null  int64
#  13  TOV          53798 non-null  int64
#  14  PF           53798 non-null  int64
#  15  ORB          53798 non-null  int64
#  16  DRB          53798 non-null  int64
#  17  REB          53798 non-null  int64
# ...

# %%
data['birth_year'] = data['birth_year'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-3700f5d286d8> in <module>
# ----> 1 data['birth_year'] = data['birth_year'].astype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ...

# %%
data['birth_year'].fillna(0, inplace=True)

# %%
data['birth_year'] = data['birth_year'].astype('int')

# %%
data.head(3)
# Out:
#   League       Season           Stage          Player Team  GP     MIN  FGM  \
# 0    NBA  2019 - 2020  Regular_Season    James Harden  HOU  68  2482.6  672
# 1    NBA  2019 - 2020  Regular_Season  Damian Lillard  POR  66  2473.7  624
# 2    NBA  2019 - 2020  Regular_Season    Devin Booker  PHX  70  2511.8  627
#
#     FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  1514  299  ...  2335        1989          Aug  Aug 26, 1989  06-May
# 1  1349  270  ...  1978        1990          Jul  Jul 15, 1990  06-Mar
# 2  1283  141  ...  1863        1996          Oct  Oct 30, 1996  06-Jun
#
#    height_cm  weight  weight_kg    nationality             high_school
# 0      196.0   220.0      100.0  United States     Artesia High School
# 1      191.0   195.0       88.0  United States     Oakland High School
# 2      198.0   206.0       93.0  United States  Moss Point High School
#
# [3 rows x 31 columns]

# %%
data["Team"].nunique()
# Out:
# 793

# %%
data['Team'].fillna("None", inplace=True)

# %%
data['Team'] = data['Team'].astype('category')

# %%
data.head(3)
# Out:
#   League       Season           Stage          Player Team  GP     MIN  FGM  \
# 0    NBA  2019 - 2020  Regular_Season    James Harden  HOU  68  2482.6  672
# 1    NBA  2019 - 2020  Regular_Season  Damian Lillard  POR  66  2473.7  624
# 2    NBA  2019 - 2020  Regular_Season    Devin Booker  PHX  70  2511.8  627
#
#     FGA  3PM  ...   PTS  birth_year  birth_month    birth_date  height  \
# 0  1514  299  ...  2335        1989          Aug  Aug 26, 1989  06-May
# 1  1349  270  ...  1978        1990          Jul  Jul 15, 1990  06-Mar
# 2  1283  141  ...  1863        1996          Oct  Oct 30, 1996  06-Jun
#
#    height_cm  weight  weight_kg    nationality             high_school
# 0      196.0   220.0      100.0  United States     Artesia High School
# 1      191.0   195.0       88.0  United States     Oakland High School
# 2      198.0   206.0       93.0  United States  Moss Point High School
#
# [3 rows x 31 columns]

# %%
data['birth_month'] = data['birth_month'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53798 entries, 0 to 53797
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   League       53798 non-null  object
#  1   Season       53798 non-null  object
#  2   Stage        53798 non-null  object
#  3   Player       53798 non-null  object
#  4   Team         53798 non-null  category
#  5   GP           53798 non-null  int64
#  6   MIN          53798 non-null  float64
#  7   FGM          53798 non-null  int64
#  8   FGA          53798 non-null  int64
#  9   3PM          53798 non-null  int64
#  10  3PA          53798 non-null  int64
#  11  FTM          53798 non-null  int64
#  12  FTA          53798 non-null  int64
#  13  TOV          53798 non-null  int64
#  14  PF           53798 non-null  int64
#  15  ORB          53798 non-null  int64
#  16  DRB          53798 non-null  int64
#  17  REB          53798 non-null  int64
# ...

# %% [markdown]
# **Challenge:**
# ##### <span style='color: green'>Take any column with int32 or int64 and convert it to float64 and observe wheather it is converting or not. If it converts, observe the memory usage wheather it is increasing or decreasing.</span>  Let me know your results in the comment section below.

# %% [markdown]
# **Useful References:**
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.astype.html
# * https://www.geeksforgeeks.org/python-pandas-dataframe-astype/
